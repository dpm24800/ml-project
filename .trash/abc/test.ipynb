# %%
import os
print(os.path.join('artifacts', 'data.csv'))
print(os.path.dirname('outer_dir/inner_dir/file.txt'))
print(os.path.dirname('outer_dir/inner_dir/file.txt'))
print(os.getcwd()) # get current working directory

# os.makedirs("dfs", exist_ok=True) # make directory
# os.removedirs("dfs") # remove directory
# # os.rmdir("dfs") # 

# os.remove('sdfsdf.tpy')
# Out:
# artifacts\data.csv
# outer_dir/inner_dir
# outer_dir/inner_dir
# c:\Users\NAN\Desktop\e2e-ml-project

# %% [markdown]
# os.makedirs(folder_path): make a direcory
# exist_ok=True: make given directory if it's not there already.
#
# os.rmdir(folder_path): removes empty directory.
# os.rmdirs(folder_path): removes empty directory.
# os.remove(file_path): remove a file
#
#
# # pandas
#
# df.to_csv(file_path, index=False, header=True)

# %%
import logging

logging.info("hey")
# logging.basicConfig('abc.log', logging.info) # logger.py: 16
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 import logging
#       3 logging.info("hey")
# ----> 4 logging.basicConfig('abc.log', logging.info)
#
# TypeError: basicConfig() takes 0 positional arguments but 2 were given

# %%
from datetime import datetime

print(datetime.now())
print(datetime.now().strftime('%Y_%m_%d_%H_%M_%S'))
# Out:
# 2026-01-28 22:48:16.521859
# 2026_01_28_22_48_16
